# %%
import pandas as pd

# %%
raw_data = pd.read_csv('C:\\Users\\Saeth\\Desktop\\HP old\\TDRI\\GitHub_LDA\\C2test_output.csv')

# %%
raw_data.head()
# Out:
#             tag_topic  [below:topic:alpha:eta]_15:100:symmetric:None.sav  \
# 0                stem                                               12.0
# 1      credit analyst                                               38.0
# 2                stem                                               90.0
# 3  accountant + audit                                                0.0
# 4   stock + inventory                                               96.0
#
#    [below:topic:alpha:eta]_15:102:symmetric:None.sav  \
# 0                                               91.0
# 1                                               63.0
# 2                                               37.0
# 3                                               33.0
# 4                                               35.0
#
#    [below:topic:alpha:eta]_15:105:symmetric:None.sav  \
# 0                                               31.0
# 1                                                1.0
# 2                                               22.0
# 3                                               91.0
# 4                                               86.0
#
#    [below:topic:alpha:eta]_15:107:symmetric:None.sav  \
# 0                                               10.0
# 1                                               25.0
# 2                                               51.0
# 3                                               25.0
# 4                                               61.0
#
#    [below:topic:alpha:eta]_15:110:symmetric:None.sav  \
# 0                                               49.0
# 1                                               42.0
# 2                                               17.0
# 3                                               83.0
# 4                                               53.0
#
#    [below:topic:alpha:eta]_15:112:symmetric:None.sav  \
# 0                                               20.0
# 1                                               98.0
# 2                                               53.0
# 3                                               43.0
# 4                                                5.0
#
#    [below:topic:alpha:eta]_15:115:symmetric:None.sav  \
# 0                                               27.0
# 1                                               28.0
# 2                                               12.0
# 3                                               28.0
# 4                                              113.0
#
#    [below:topic:alpha:eta]_15:117:symmetric:None.sav  \
# 0                                               99.0
# 1                                               74.0
# 2                                               82.0
# 3                                               94.0
# 4                                              114.0
#
#    [below:topic:alpha:eta]_15:120:symmetric:None.sav  ...  \
# 0                                                4.0  ...
# 1                                               57.0  ...
# 2                                               85.0  ...
# 3                                                7.0  ...
# 4                                               98.0  ...
#
#    [below:topic:alpha:eta]_15:75:symmetric:None.sav  \
# 0                                                15
# 1                                                58
# 2                                                22
# 3                                                60
# 4                                                20
#
#    [below:topic:alpha:eta]_15:77:symmetric:None.sav  \
# 0                                                70
# 1                                                27
# 2                                                55
# 3                                                41
# 4                                                22
#
#    [below:topic:alpha:eta]_15:80:symmetric:None.sav  \
# 0                                                74
# 1                                                63
# 2                                                45
# 3                                                31
# 4                                                48
#
#    [below:topic:alpha:eta]_15:82:symmetric:None.sav  \
# 0                                                19
# 1                                                 8
# 2                                                 3
# 3                                                 0
# 4                                                 5
#
#    [below:topic:alpha:eta]_15:85:symmetric:None.sav  \
# 0                                                69
# 1                                                14
# 2                                                31
# 3                                                67
# 4                                                44
#
#    [below:topic:alpha:eta]_15:87:symmetric:None.sav  \
# 0                                                34
# 1                                                45
# 2                                                24
# 3                                                32
# 4                                                44
#
#    [below:topic:alpha:eta]_15:90:symmetric:None.sav  \
# 0                                                38
# 1                                                32
# 2                                                 8
# 3                                                49
# 4                                                19
#
#    [below:topic:alpha:eta]_15:92:symmetric:None.sav  \
# 0                                                63
# 1                                                72
# 2                                                57
# 3                                                 1
# 4                                                29
#
#    [below:topic:alpha:eta]_15:95:symmetric:None.sav  \
# 0                                                89
# 1                                                83
# 2                                                74
# 3                                                76
# 4                                                 4
#
#    [below:topic:alpha:eta]_15:97:symmetric:None.sav
# 0                                                 0
# 1                                                78
# 2                                                51
# 3                                                50
# 4                                                91
#
# [5 rows x 42 columns]

# %%
job_label=list(raw_data['tag_topic'].unique())
target = ['stem', 'therapist', 'coordinator high skill', 'buesiness develop', 'coordinator low skill', 'finance manager',
          'investor + trader + risk management', 'product', 'supply and distribution manager', 'event organizer', 
          'teacher art', 'teacher academics', 'flim', 'gardener', 'craftman', 'teacher music', 'teacher sport',
          'policy and planing manager', 'entertainer', 'business service and admin manager', 'health service manager',
          'education manager', 'tour guider', 'librarian', 'artist', 'drama writer', 'r and d manager', 'photographer',
          'advertising and public relation manager', 'interior archetecture', 'writing creator', 'other managers']
for i in target:
    job_label.pop(job_label.index(i))
job_label
# Out:
# ['credit analyst',
#  'accountant + audit',
#  'stock + inventory',
#  'sale',
#  'sale and marketing manager',
#  'manufacturing manager',
#  'marketing',
#  'procurement + logistic',
#  'customer service',
#  'waiter',
#  'retail manager',
#  'law',
#  'telesale',
#  'hr manager',
#  'graphic design',
#  'vehicle driver',
#  'translator',
#  'maid',
#  'cooker + bartender',
#  'HR',
#  'security + safety',
#  'architecture',
#  'cashier',
#  'care taker',
#  'pr + ae']

# %%
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

raw_column=list(raw_data.columns)
raw_column.remove('tag_topic')
select_column=raw_column
#job distribution for 1 model

warnings.filterwarnings('ignore')

for model in select_column[:30]:
  plt.figure(figsize=(15,10))
  for job in job_label:
    sns.distplot(raw_data[raw_data['tag_topic']==job][model], label=job, bins=1)
    plt.legend()
